# %%
from finmarket_lab.market_data.bybit import parse_orderbook 
from finmarket_lab.storage.reader import OrderbookReader
from finmarket_lab.visualization.orderbook_visualization import OrderbookView

rdo = OrderbookReader('../data/raw/BTCUSDT/orderbook_data.jsonl')
out = rdo.read_all()

message = out[0]
bids, asks = parse_orderbook(message)

orderbook_view = OrderbookView()
orderbook_view.display(bids, asks)

# %%
from examples.demo_orderbook_realtime import main as realtime
from IPython.display import clear_output, display as notebook_display

realtime()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from examples.demo_orderbook_realtime import main as realtime
#       2 from IPython.display import clear_output, display as notebook_display
# ----> 4 realtime()
#
# File /workspace/examples/demo_orderbook_realtime.py:38, in main()
#      35 receive_thread.start()
#      36 saver_thread.start()
# ---> 38 viewer(display_queue=display_queue)
#
# File /workspace/examples/demo_orderbook_realtime.py:16, in viewer(display_queue)
#      14 bids, asks = parse_orderbook(display_queue.get())
#      15 orderbook_view.display(bids,asks)
# ---> 16 time.sleep(0.1)
#
# KeyboardInterrupt:
# WebSocket Unified V5 (wss://stream.bybit.com/v5/public/linear) encountered error: Connection to remote host was lost..
